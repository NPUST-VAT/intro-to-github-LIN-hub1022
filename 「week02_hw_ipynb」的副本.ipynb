# %% [markdown]
# <a href="https://colab.research.google.com/github/NPUST-VAT/intro-to-github-LIN-hub1022/blob/main/%E3%80%8Cweek02_hw_ipynb%E3%80%8D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 作業：變數、資料型態與基本運算
#
# **農園生產系：運算思維與資訊科技應用課程**
#
# ---
#
# ## 操作說明
#
# 1. 先執行下方的「安裝＆初始化」區塊（輸入你的學號）
# 2. 閱讀每一題的題目說明
# 3. 在「 在這裡寫你的答案」的程式格裡寫程式
# 4. 執行「 檢查答案」的程式格來確認是否正確
# 5. 最後執行「check_all()」看總結

# %% [markdown]
# ---
# ## 安裝＆初始化
# 請先執行下面這個程式格，並把學號改成你自己的。

# %%
# !pip install npust-py-checker
from checker import week02

# ⬇ 請把引號裡面改成你的學號
week02.init("B11411008")
# Out:
# ...
# ✅ 學號 B11411008 已登記，開始作答吧！

# %% [markdown]
# #上課測試區域

# %%
# 在此輸入程式碼

# %% [markdown]
# ---
# ## Q1：稻米平均產量（整數運算）
#
# 屏科大農場今年的稻米總產量是 **13500 公斤**，這些稻米來自 **3 塊田**。
#
# 請計算每塊田的平均產量（公斤），並將結果存成變數 `avg_yield`。
#
# **注意**：答案必須是**整數**（`int`），不能是小數（`float`）。
#
# ```python
# # 提示：整數除法用 //
# ```

# %%
# 在這裡寫你的答案

total_yield = 13500 # 總產量（公斤）
num_fields = 3 # 田的數量

avg_yield = total_yield//num_fields # 把 ... 換成你的計算式

# %%
#  檢查答案（執行這格來確認）
try:
    week02.check_q1(avg_yield)
except NameError as e:
    print(f" 變數 {e.name} 尚未定義，請先完成上方的程式碼再執行此格。")
# Out:
#     <div style="padding:12px 16px;border-radius:8px;background:#d4edda;border:1px solid #c3e6cb;margin:8px 0;">
#         <span style="font-size:20px;">✅</span>
#         <strong style="color:#155724;margin-left:8px;">Q1 稻米平均產量 — 答對囉！你很厲害！</strong>
#     </div>

# %% [markdown]
# ---
# ## Q2：平均溫度（浮點數與四捨五入）
#
# 屏東某農場記錄了一週七天的最高溫度（°C）：
#
# | 一 | 二 | 三 | 四 | 五 | 六 | 日 |
# |---|---|---|---|---|---|---|
# | 28.3 | 30.1 | 29.5 | 31.2 | 27.8 | 30.6 | 29.9 |
#
# 請計算這七天的**平均溫度**，並**四捨五入到小數點後一位**，存成變數 `avg_temp`。
#
# ```python
# # 提示：round(數值, 位數)
# ```

# %%
# 在這裡寫你的答案

temps = [28.3, 30.1, 29.5, 31.2, 27.8, 30.6, 29.9] # 七天溫度

avg_temp = avg_temp = round(sum(temps) / len(temps), 1)
 # 把 ... 換成你的計算式

# %%
#  檢查答案（執行這格來確認）
try:
    week02.check_q2(avg_temp)
except NameError as e:
    print(f" 變數 {e.name} 尚未定義，請先完成上方的程式碼再執行此格。")
# Out:
#     <div style="padding:12px 16px;border-radius:8px;background:#d4edda;border:1px solid #c3e6cb;margin:8px 0;">
#         <span style="font-size:20px;">✅</span>
#         <strong style="color:#155724;margin-left:8px;">Q2 平均溫度 — 正確！做得好！</strong>
#     </div>

# %% [markdown]
# ---
# ## Q3：農場資訊（字串與布林值）
#
# 已知以下農場資訊：
# ```python
# farm_name = "屏科大實習農場"
# area_hectares = 55 # 公頃
# ```
#
# 請完成兩件事：
#
# **(a)** 用 **f-string** 建立一個字串，格式為：`「{farm_name}的面積是{area_hectares}公頃」`，存成變數 `farm_info`
#
# **(b)** 判斷這個農場的面積**是否大於 50 公頃**，將結果存成變數 `is_large_farm`（`True` 或 `False`）

# %%
# 在這裡寫你的答案

farm_name = "屏科大實習農場"
area_hectares = 55

farm_info = f"{farm_name}的面積是{area_hectares}公頃"
is_large_farm = area_hectares > 50

print(farm_info)
print(is_large_farm)
# Out:
# 屏科大實習農場的面積是55公頃
# True

# %%
#  檢查答案（執行這格來確認）
try:
    week02.check_q3(farm_info, is_large_farm)
except NameError as e:
    print(f" 變數 {e.name} 尚未定義，請先完成上方的程式碼再執行此格。")
# Out:
#  變數 week02 尚未定義，請先完成上方的程式碼再執行此格。

# %% [markdown]
# ---
# ## 作業總結
#
# 完成所有題目後，執行下方程式格查看總成績：

# %%
# 顯示作業總結
week02.check_all()
